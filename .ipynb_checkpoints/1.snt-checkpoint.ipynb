# %%
from scipy.stats import gaussian_kde
from matplotlib.gridspec import GridSpec
from sklearn.metrics import pairwise_distances
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import sklearn
from matplotlib.patches import Patch
from statsmodels.multivariate.cancorr import CanCorr

#----------------------------------------------
from project_utils import * 

# main_dir = f'{user}/Desktop/SNT_data/SNT-online_behavioral/Data'
data = pd.read_excel('../../All-data_summary_n877.xlsx') # new factors included
fa01 = pd.read_excel('../../FA01_n912.xlsx') # social, mood, compulsive factors
data = data.merge(fa01)
data.reset_index(drop=True, inplace=True)

# %%
# asymmetrical correlation matrices
def get_asymmetrical_corrmat(x_df_, y_df_, linear_correlation=scipy.stats.pearsonr, permutations=None):
    '''
        x_df & y_df should dfs of shape num_subs x num_variables
        robust to diff. amounts of missingness for diff. variables
        will do nonparametric correlations if specified & angular-angular & angular-linear correlations 
        also will do permutation testing
    '''
    
    x_df = x_df_.copy()
    y_df = y_df_.copy()

    y_cols = y_df.columns
    x_cols = x_df.columns
    
    # avoid problems with data type
    x_df[x_cols] = x_df[x_cols].apply(pd.to_numeric, downcast='float', errors='coerce')
    y_df[y_cols] = y_df[y_cols].apply(pd.to_numeric, downcast='float', errors='coerce')
    
    # turn any angles into radians...
    y_angles = ['angles' in c for c in y_cols]
    x_angles = ['angles' in c for c in x_cols]
    y_df[y_cols[y_angles]] = y_df[y_cols[y_angles]].apply(np.deg2rad) 
    x_df[x_cols[x_angles]] = x_df[x_cols[x_angles]].apply(np.deg2rad) 

    # for outputting
    coefs = np.zeros((len(y_cols), len(x_cols)))
    pvals = np.zeros((len(y_cols), len(x_cols)))
    
    for yi, y_col in enumerate(y_cols):
        for xi, x_col in enumerate(x_cols):

            # screen out subs w/ nans & infs 
            finite_mask = np.isfinite(x_df[x_col].values) * np.isfinite(y_df[y_col].values) 
            x = x_df[x_col][finite_mask]
            y = y_df[y_col][finite_mask]
            
            # correlation 
            if ('angles' not in x_col) & ('angles' not in y_col):
                correlation = linear_correlation 
            elif (('angles' in x_col) & ('angles' not in y_col)):
                correlation = circ_corrcl
            elif (('angles' not in x_col) & ('angles' in y_col)):
                correlation = circ_corrcl 
                y = x_df[x_col][finite_mask] # flip the order of circular & linear variables
                x = y_df[y_col][finite_mask]
            elif ('angles' in x_col) & ('angles' in y_col):
                correlation = circ_corrcc
            coefs[yi,xi], pvals[yi,xi] = correlation(x, y)
            
            # permutation significance testing
            if permutations: 
                perm_coefs = np.zeros(permutations)
                y_ = y.copy().values
                for n in range(permutations):
                    random.shuffle(y_)
                    perm_coefs[n], _ = correlation(x, y_)
                pvals[yi,xi] = get_perm_pval(coefs[yi,xi], perm_coefs, test='2-sided')
                
    corr_mat = pd.DataFrame(coefs, index=y_cols, columns=x_cols)
    pval_mat = pd.DataFrame(pvals, index=y_cols, columns=x_cols)
    return corr_mat, pval_mat


def plot_asymmetrical_corrmat(corr_mat, pval_mat, figsize=(15,15)):
    '''
    '''
    x_names  = corr_mat.columns
    y_names  = corr_mat.index
    corr_mat = corr_mat.values.copy()
    pval_mat = pval_mat.values.copy()

    # masked correlation plot
    masked_corrs = corr_mat * ((pval_mat < 0.05) * 1) 
    fig, ax = plt.subplots(figsize=figsize)
    im = ax.imshow(masked_corrs, cmap="RdBu_r", vmax=1, vmin=-1) #np.max(masked_corrs)
    plt.grid(False)
    
    # 0.05: *, 0.01: **, 0.001: ***, <0.0001: ****
    for i in np.arange(len(y_names)):
        for j in np.arange(len(x_names)):
            if corr_mat[i,j] > 0.50:
                color = 'white'
            else:
                color = 'black'
            if pval_mat[i,j] < 0.0001:
                sig = '****'
            elif pval_mat[i,j] < 0.001:
                sig = '***'
            elif pval_mat[i,j] < 0.01:
                sig = '**'
            elif pval_mat[i,j] < 0.05:
                sig = '*'
            else:
                sig = ' '
            text = ax.text(j, i, sig, ha="center", va="center", color=color, fontsize=20)
            
    im_ratio = corr_mat.shape[0]/corr_mat.shape[1] # (height_of_image / width_of_image)
    # cbar = plt.colorbar(ax.get_children()[-2], ax=ax, orientation='vertical', fraction=0.044*im_ratio)
    # cbar.set_label(label='Correlation', size=20)
    # cbar.ax.tick_params(labelsize=9)

    ax.set_yticks(np.arange(len(y_names)))
    ax.set_yticklabels(y_names, fontsize=15)
    ax.set_xticks(np.arange(len(x_names)))
    ax.set_xticklabels(x_names, fontsize=15, rotation=90)

    # add grid lines
    ax.set_xticks(np.arange(-.5, len(x_names), 1), minor=True)
    ax.set_yticks(np.arange(-.5, len(y_names), 1), minor=True)
    ax.grid(which='minor', color='black', linestyle='-', linewidth=1.5)
    
    ax.set_title('Correlations', fontsize=20)

    return fig
def plot_space_density(x, y, figsize=(5,5), regression=False):
    
    '''
    '''
    
    xy = np.vstack([x, y])
    z  = gaussian_kde(xy)(xy) # point density

    # sort so that the bright spots are on top
    idx = z.argsort()
    x, y, z = x[idx], y[idx], z[idx]

    # plot
    fig, axs = plt.subplots(2, 2, figsize=figsize, 
                                  gridspec_kw={'hspace': 0, 'wspace': 0,
                                               'width_ratios': [5, 1], 'height_ratios': [1, 5]})
    axs[0,0].axis("off")
    axs[0,1].axis("off")
    axs[1,1].axis("off")
    sns.distplot(x, bins=20, ax=axs[0,0], color="Black")
    sns.distplot(y, bins=20, ax=axs[1,1], color="Black", vertical=True)
    axs[1,0].axhline(y=0, color='black', linestyle='-', zorder=-1)
    axs[1,0].axvline(x=0, color='black', linestyle='-', zorder=-1)
    axs[1,0].scatter(x, y, c=z, s=100)
    
    if regression: sns.regplot(x, y, scatter=False, color='black', ax=axs[1,0])
    
    axs[1,0].set_ylim([-1,1])
    axs[1,0].set_yticks([-1,-.5,0,.5,1])
    axs[1,0].set_xlim([-1,1])
    axs[1,0].set_xticks([-1,-.5,0,.5,1])
    
    plt.show()

# %% [markdown]
# # Compute extra variables

# %%
if os.path.exists(f'../../taskVdots_n{len(data)}.xlsx'):
    dists_df = pd.read_excel(f'../../taskVdots_n{len(data)}.xlsx')
else:
    dists_df = pd.DataFrame()
    for s, data_ in data.iterrows(): 

        dists_df.loc[s, 'sub_id'] = data_['sub_id']

        # organize x,y - only the 5 real characters
        task_data = data_[['affil_mean_first','power_mean_first',
                           'affil_mean_second','power_mean_second',
                           'affil_mean_assistant','power_mean_assistant',
                           'affil_mean_powerful','power_mean_powerful',
                           'affil_mean_boss','power_mean_boss']].values
        dots_data = data_[['first_dots_affil','first_dots_power',
                           'second_dots_affil','second_dots_power',
                           'assistant_dots_affil','assistant_dots_power',
                           'powerful_dots_affil','powerful_dots_power',
                           'boss_dots_affil','boss_dots_power']].values


        #----------------------------------------------------------------------------------------
        # CHARACTER BY CHARACTER
        #----------------------------------------------------------------------------------------

        ori_xy  = np.array([[1,0]])
        task_xy = task_data.reshape(5,2).astype(float)
        dots_xy = dots_data.reshape(5,2).astype(float)    

        #--------------------------------------------
        # direct dots to task distances
        #--------------------------------------------


        # 1d distances
        dists_1d = task_xy - dots_xy 
        dists_df.loc[s, [f'taskVdots_affil_{role}' for role in character_roles[0:5]]] = dists_1d[:,0] # do dots get larger afiliation value?
        dists_df.loc[s, [f'taskVdots_power_{role}' for role in character_roles[0:5]]] = dists_1d[:,1] # no real hypothesis

        # 2d distances
        dists_df.loc[s, [f'taskVdots_dist_{role}' for role in character_roles[0:5]]] = pairwise_distances(task_xy, dots_xy).diagonal()


        #--------------------------------------------
        # diff in distances to common reference
        #--------------------------------------------
        # ori = np.array((6, -4)) / 6

        task_dist  = pairwise_distances(task_xy, ori_xy)
        dots_dist  = pairwise_distances(dots_xy, ori_xy)

        dists_df.loc[s, [f'dots_pov_dist_{role}' for role in character_roles[0:5]]]           = dots_dist.flatten()
        dists_df.loc[s, [f'taskVdots_pov_dist_diff_{role}' for role in character_roles[0:5]]] = task_dist.flatten() - dots_dist.flatten()

        # calculate_angle(task_pos - ori, dots_pos - ori,force_pairwise=False, direction=None)


        #----------------------------------------------------------------------------------------
        # WHOLE SHAPE
        #----------------------------------------------------------------------------------------


        #-----------------------------------------------------------
        # RSA: pairwise distances 
        #-----------------------------------------------------------

        # 1d
        affil_task_rdv = symm_mat_to_ut_vec(pairwise_distances(task_xy[:,0][:,np.newaxis]))
        affil_dots_rdv = symm_mat_to_ut_vec(pairwise_distances(dots_xy[:,0][:,np.newaxis]))
        dists_df.loc[s, f'taskVdots_affil_dist_tau'] = scipy.stats.kendalltau(affil_dots_rdv, affil_task_rdv)[0]

        power_task_rdv = symm_mat_to_ut_vec(pairwise_distances(task_xy[:,1][:,np.newaxis]))
        power_dots_rdv = symm_mat_to_ut_vec(pairwise_distances(dots_xy[:,1][:,np.newaxis]))
        dists_df.loc[s, f'taskVdots_power_dist_tau'] = scipy.stats.kendalltau(power_dots_rdv, power_task_rdv)[0]

        # 2d
        origins  = {'neu': [0,0], 'pov': [1,0]}
        metrics  = ['cosine', 'euclidean', 'cityblock']
        for ori, ori_xy in origins.items():
            for m, metric in enumerate(metrics): 
                # rsa: distance across characters
                dots_rdv = symm_mat_to_ut_vec(pairwise_distances(dots_xy - ori_xy, metric=metric))
                task_rdv = symm_mat_to_ut_vec(pairwise_distances(task_xy - ori_xy, metric=metric))
                dists_df.loc[s, f'taskVdots_{ori}_{metric}_dist_tau'] = scipy.stats.kendalltau(dots_rdv, task_rdv)[0]

        #-----------------------------------------------------------
        # areas etc
        #-----------------------------------------------------------

        # area = scipy.spatial.ConvexHull(dots_xy).volume


        #-----------------------------------------------------------
        # procrustes transformation
        # - transfroms one shape to fit the other
        # - the disparity is point-wise euclidean distance it is trying to minimize
        #-----------------------------------------------------------

        dists_df.loc[s, 'taskVdots_procDisp'] = scipy.spatial.procrustes(dots_xy, task_xy)[2] # disparity shouldnt matter on order

        #-----------------------------------------------------------
        # not sure what orthogonal procrustes is
        #-----------------------------------------------------------

        # _, scale = scipy.linalg.orthogonal_procrustes(task_xy, dots_xy) # (to_map, map_to)

        #-----------------------------------------------------------
        # mean elementwise euclidean distance from dots to task
        #-----------------------------------------------------------

        dists_df.loc[s, 'taskVdots_dist_mean'] = np.mean(scipy.spatial.distance.cdist(task_xy, dots_xy, 'euclidean').diagonal())

        #-----------------------------------------------------------
        # use least squares to get transform from
        # -- task @ transform = dots
        #-----------------------------------------------------------

        # - this returns a residual for both dims (i think).... could be useful?
        _, res, _ , _ = np.linalg.lstsq(task_xy, dots_xy, rcond=None)
        try: 
            dists_df.loc[s, 'taskVdots_lstsqRes_affil'] = res[0]
            dists_df.loc[s, 'taskVdots_lstsqRes_power'] = res[1]
        except:
            dists_df.loc[s, 'taskVdots_lstsqRes_affil'] = np.nan
            dists_df.loc[s, 'taskVdots_lstsqRes_power'] = np.nan


    # means of elementwise comparisons
    dists_df['dots_pov_dist_mean']      = np.mean(dists_df[[c for c in dists_df.columns if ('dots_pov_dist_' in c) & ('task' not in c)]], 1)
    dists_df['taskVdots_pov_dist_mean'] = np.mean(dists_df[[c for c in dists_df.columns if 'taskVdots_pov_dist_' in c]], 1)
    dists_df['taskVdots_dist_mean']     = np.mean(dists_df[[c for c in dists_df.columns if 'taskVdots_dist_' in c]], 1)
    dists_df['taskVdots_power_mean']    = np.mean(dists_df[[c for c in dists_df.columns if 'taskVdots_power_' in c]], 1)
    dists_df['taskVdots_affil_mean']    = np.mean(dists_df[[c for c in dists_df.columns if 'taskVdots_affil_' in c]], 1)
    dists_df.to_excel(f'../../taskVdots_n{len(dists_df)}.xlsx', index=False)

data = data.merge(dists_df)

# %% [markdown]
# # QC: memory & rt
# - ensure a solid threshold
# - consider it as a covariate

# %%
print(f"Initial n={np.sum(data['sample']==0)}")
print(f"Replication n={np.sum(data['sample']==1)}")

# %%
# memory check
fig,axs = plt.subplots(1, 7, figsize=(15,2), sharey=True)
sns.histplot(data['memory_mean'], ax=axs[0])
axs[0].axvline(x=.2, color='black')
axs[0].set_xlim(0, 1)
axs[0].set_xticks([0,.5,1])
for r,role in enumerate(character_roles): 
    sns.histplot(data[f'memory_{role}'], color='grey', ax=axs[1+r], bins=5)
    axs[1+r].set_xlim(0, 1)
    axs[1+r].set_xticks([0,.5,1])
plt.tight_layout()
plt.show()

# print out n at diff thresholds
for thresh in [.2, .33, .5]: 
    print(f"memory threshold={thresh}, n={np.sum(data['memory_mean'] > thresh)}")
# Out:
# memory threshold=0.2, n=912
# memory threshold=0.33, n=898
# memory threshold=0.5, n=827

# %% [markdown]
# # Behavioral analysis

# %% [markdown]
# ## Behavioral affiliation & power are correlated, across people
# - Cant naively assume orthogonality
# Feel like the underlying space could still be orthogonal: a directional bias doesnt mean x,y is non-orthogonal

# %%
fig, axs = plt.subplots(1, 6, figsize=(20, 3.75), sharey=True)
fig.subplots_adjust(top=0.95)
fig.text(0.515, -0.02, 'Affiliation', ha='center', fontsize=20)
fig.text(0, 0.5, 'Power', va='center', rotation='vertical', fontsize=20)

for c in range(0,5):
    char = character_roles[c]
    sns.regplot(x=f'affil_mean_{char}', y=f'power_mean_{char}', data=data, 
                x_jitter=.1, y_jitter=.1,
                scatter_kws={'alpha':0.6}, #color=character_colors[c],
                ax=axs[c])
    axs[c].set_xlim(-1,1)
    axs[c].set_ylim(-1,1)
    axs[c].axhline(y=0, color='black')
    axs[c].axvline(x=0, color='black')
    axs[c].set_xlabel('')
    axs[c].set_ylabel('')
    axs[c].set_title(character_roles[c].capitalize(), fontsize=20)

sns.regplot(x=f'affil_mean_{char}', y=f'power_mean_{char}', data=data, 
            x_jitter=.1, y_jitter=.1, 
            scatter_kws={'alpha':0.6}, color='darkblue',
            ax=axs[5])
axs[5].set_xlim(-1,1)
axs[5].set_ylim(-1,1)
axs[5].axhline(y=0, color='black')
axs[5].axvline(x=0, color='black')
axs[5].set_xlabel('')
axs[5].set_ylabel('')
axs[5].set_title('Mean', fontsize=20)

plt.tight_layout()
plt.show()

# %%
# fig, axs = plt.subplots(1,5, figsize=(50,10), subplot_kw=dict(projection="polar"))
# for c in range(5):
#     radians = np.deg2rad(all_df['allo2d_angles_end_' + character_roles[c]]).values
#     n,bins,patches = circular_hist(axs[c], radians, color=character_colors[c])
#     axs[c].set_title(character_roles[c], fontsize=20)

# %% [markdown]
# ## random things to try
# #### Can we use 4/5 characters to infer 5th?
# #### vector navigation model?

# %%
# vector_total = vector_change + vector_previous

# %%
distances = data[['pov_dist_first','pov_dist_second','pov_dist_assistant','pov_dist_powerful','pov_dist_boss']]
radians   = data[['pov_2d_angle_first','pov_2d_angle_second','pov_2d_angle_assistant','pov_2d_angle_powerful','pov_2d_angle_boss']]

for character in character_roles[0:5]:
    
    others = [c for c in character_roles[0:5] if c is not character]
    
    #------------------------------------
    # distance & angle at end
    #------------------------------------
    
    curr         = data[[f'pov_dist_{character}', f'pov_2d_angle_{character}']].values
    other_dists  = data[[f'pov_dist_{c}' for c in others]].values
    other_angles = data[[f'pov_2d_angle_{c}' for c in others]].values
    
    #------------------------------------
    # location at end
    #------------------------------------

    curr_xy = data[[f'affil_coord_{character}', f'power_coord_{character}']].values
    other_x = data[[f'affil_coord_{c}' for c in others]].values
    other_y = data[[f'power_coord_{c}' for c in others]].values

    other_xy_avg = np.vstack([np.mean(other_x, axis=1), np.mean(other_y, axis=1)]).T
    data[[f'affil_diff_{character}', f'power_diff_{character}']] = other_xy_avg - curr_xy # how far off from the group is this character?
    data[f'euc_distance_{character}'] = pairwise_distances(curr_xy, other_xy_avg).diagonal() # character's contribution to area, in a sense
    data[f'cosine_distance_{character}'] = pairwise_distances(curr_xy, other_xy_avg, metric='cosine').diagonal() # character's contribution to area, in a sense

data['avg_euc_dist_from_others'] = np.mean(data[[f'euc_distance_{c}' for c in character_roles[0:5]]], axis=1) # this is just like area...?
data['avg_cos_dist_from_others'] = np.mean(data[[f'cosine_distance_{c}' for c in character_roles[0:5]]], axis=1) # this is just like area...?

# %%
fig,axs = plt.subplots(1, 5, figsize=(10,2), sharey=True)
for c,character in enumerate(character_roles[0:5]):
    sns.histplot(data[f'cosine_distance_{character}'], ax=axs[c])
    axs[c].set_xlim(0, 2)
#     axs[c].set_xticks([0,.5,1])
plt.tight_layout()
plt.show()

# %%
# # OBSERVED:
# # euclidean & cosine distance highly corr. across characters... 
# # - both just makers of area... not cool

# sns.regplot(x=data['avg_cos_dist_from_others'], 
#             y=data['avg_euc_dist_from_others'])
# plt.show()

# %%
# how to do significance testing here?
# i guess average distance across characters could be corrwlated w/ social avoidance?

# %% [markdown]
# # Subjective 2D map-like representations
# - Doesnt necessarily have to precisely match...
# - Behavior reflects relationship (e.g., the other person can see behavior, respond to it, etc)
# - Dots reflects internal feelings

# %% [markdown]
# ### Dots dimensions are correlated
# People have a slight bias to (+,+) in dots, similar to slight bias in behavior

# %%
plot_space_density(data['dots_power_mean'].values, data['dots_affil_mean'].values, regression=False)

# %% [markdown]
# ### Average dimension-specific task & dots locations are highly correlated
# CCA: the correlations are very similar to the standardized regression coefs, but pvalues are diff... lack of control?
#
# TODO: plot the cross dims too... dots-task-ratings maybe can give us an idea of the fakeyness of behavior

# %%
affl_var  = 'affil_mean_mean' # 'likability_mean'
power_var = 'power_mean_mean' # 'impact_diff_mean'
mask = np.isfinite(data['dots_power_mean']) & np.isfinite(data[power_var])

#-----------------------------------------------------------------------------

fig, axs = plt.subplots(1, 2, figsize=(6.5, 3))

sns.regplot(x=data['dots_affil_mean'], y=data[affl_var], 
            scatter_kws={'alpha':0.15, 's':30},
            color='blue', ax=axs[0])
axs[0].tick_params(axis='x', labelsize=8)
axs[0].tick_params(axis='y', labelsize=8)
axs[0].set_xlim(-1,1)
axs[0].set_xticks([-1,-.5,0,.5,1])
axs[0].set_ylim(-1,1)
axs[0].set_yticks([-1,-.5,0,.5,1])
axs[0].set_ylabel('Task: affiliation', fontsize=14)
axs[0].set_xlabel('Dots: affiliation', fontsize=14)
axs[0].axhline(y=0, color='black', linestyle='-', zorder=-1)
axs[0].axvline(x=0, color='black', linestyle='-', zorder=-1)


sns.regplot(x=data['dots_power_mean'], y=data[power_var], 
            scatter_kws={'alpha':0.15, 's':30}, # 'edgecolor':'black'},
            color='red', ax=axs[1])
axs[1].tick_params(axis='x', labelsize=8)
axs[1].tick_params(axis='y', labelsize=8)
axs[1].set_xlim(-1,1)
axs[1].set_xticks([-1,-.5,0,.5,1])
axs[1].set_ylim(-1,1)
axs[1].set_yticks([-1,-.5,0,.5,1])
axs[1].set_ylabel('Task: power', fontsize=14)
axs[1].set_xlabel('Dots: power', fontsize=14)
axs[1].axhline(y=0, color='black', linestyle='-', zorder=-1)
axs[1].axvline(x=0, color='black', linestyle='-', zorder=-1)

plt.tight_layout()
plt.show()

#-----------------------------------------------------------------------------

# print(run_ols([affl_var] + ['memory_mean'], 'dots_affil_mean', data[mask], demo_controls)[0])
# print(run_ols([power_var] + ['memory_mean'], 'dots_power_mean', data[mask], demo_controls)[0])

# CCA approach:
task = data[['affil_mean_mean', 'power_mean_mean']]
dots = data[['dots_affil_mean', 'dots_power_mean', 'memory_mean']]
task = scipy.stats.zscore(task[mask])
dots = scipy.stats.zscore(dots[mask])
stats_cca = CanCorr(task, dots) # order doesnt matter
print(stats_cca.corr_test().summary())
# Out:
#                            Cancorr results
# ...
#   Canonical Correlation Wilks' lambda Num DF   Den DF  F Value Pr > F
# ---------------------------------------------------------------------
# 0                0.2492        0.9285 6.0000 1822.0000 11.4749 0.0000
# 1                0.1002        0.9900 2.0000  912.0000  4.6253 0.0100
# ---------------------------------------------------------------------
#
# ---------------------------------------------------------------------
# Multivariate Statistics and F Approximations
# -----------------------------------------------------------------------
#                          Value    Num DF     Den DF    F Value   Pr > F
# -----------------------------------------------------------------------
# Wilks' lambda            0.9285   6.0000   1820.0000   11.4623   0.0000
# Pillai's trace           0.0721   6.0000   1822.0000   11.3600   0.0000
# Hotelling-Lawley trace   0.0763   6.0000   1211.5572   11.5707   0.0000
# ...

# %% [markdown]
# ### RSA of dimension-specific euclidean distances between task & dots locations fails... the boss is probably distorting?

# %%
affil_taus = data['taskVdots_affil_dist_tau']
power_taus = data['taskVdots_power_dist_tau']

# plot
fig, axs = plt.subplots(1, 2, figsize=(6.5, 3))
sns.histplot(affil_taus, color='blue', ax=axs[0])
sns.histplot(power_taus, color='red', ax=axs[1])
plt.tight_layout()
plt.show()
print(scipy.stats.wilcoxon(np.array(affil_taus)[np.isfinite(affil_taus)], alternative='greater'))
print(scipy.stats.wilcoxon(np.array(power_taus)[np.isfinite(power_taus)], alternative='greater'))
# Out:
# WilcoxonResult(statistic=159548.5, pvalue=0.9994079867651355)
# WilcoxonResult(statistic=193238.5, pvalue=0.061131997740994044)

# %% [markdown]
# ### RSA of 2D distances between task & dots: statistically significant w/ euclidean & cosine distance

# %%
for ori in ['neu', 'pov']:
    metrics = ['euclidean', 'cosine', 'cityblock']
    fig, axs = plt.subplots(1, len(metrics), figsize=(3.25*len(metrics), 3))
    for m, dist in enumerate(metrics):
    
        # run stats
        stats = np.array(data[f'taskVdots_{ori}_{dist}_dist_tau'].values)
        print(scipy.stats.wilcoxon(stats[np.isfinite(stats)], alternative='greater'))

        # plot
        sns.histplot(stats, color='purple', ax=axs[m])
        axs[m].set_title(f'{ori} origin: {dist} distance', fontsize=12)
        
    plt.tight_layout()
    plt.show()
# Out:
# WilcoxonResult(statistic=209254.5, pvalue=0.006514192511555921)
# WilcoxonResult(statistic=216756.5, pvalue=0.0009521643005880287)
# WilcoxonResult(statistic=213345.0, pvalue=0.004815552745625999)
# WilcoxonResult(statistic=209724.5, pvalue=0.006511223939746059)
# WilcoxonResult(statistic=237275.5, pvalue=2.4085413081127473e-13)
# WilcoxonResult(statistic=213502.0, pvalue=0.004532162201862625)

# %% [markdown]
# ### Distance between task & dots: something like behavior v. feelings mismatch?
# Boss is the most discrepant
# - Maybe we can learn soemthing from this boss thing?
#     - E.g., are the nicest acting peopel the most likely to affiliate, despite their internal feelings?
#
# 1D measures: dots - behavior
# - dist ~ 0: behavior is aligned w/ dots
# - dist < 0: behavior > dots (projecting somethng you dont feel?)
# - dist > 0: dots > behavior (hiding something you do feel?)
#
# this all assumes that the decisions are all the same weights across characters, which might not be true...

# %%
fig, axs = plt.subplots(3, 5, figsize=(10, 6))
for r, role in enumerate(character_roles[0:5]):
    for x, xvar in enumerate(['taskVdots_dist', 'taskVdots_affil', 'taskVdots_power']):
        dists = data[f'{xvar}_{role}']
        
        if 'affil' in xvar: 
            axs[x,r].set_xlim(-2.5, 2.5)
            axs[x,r].axvline(x=0, color='black', linewidth=2)
            sns.histplot(dists[dists<=0], color='grey', ax=axs[x,r], stat='count')
            sns.histplot(dists[dists>0], color='blue', ax=axs[x,r], stat='count')
            axs[x,r].set_ylim(0,175)
        elif 'power' in xvar:
            axs[x,r].set_xlim(-2.5, 2.5)
            axs[x,r].axvline(x=0, color='black', linewidth=2)
            sns.histplot(dists[dists<=0], color='grey', ax=axs[x,r], stat='count')
            sns.histplot(dists[dists>0], color='red', ax=axs[x,r], stat='count')
            axs[x,r].set_ylim(0,175)
        else:
            axs[x,r].set_xlim(0,3)
            sns.histplot(dists, color='purple', ax=axs[x,r])
        
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Does mismatch relate to...

# %% [markdown]
# #### Emotion: maybe the more the mismatch between internal & external, the more emotional?
# Less positive the greater the distance between the task & dots

# %%
data['arousal2_mean'] = np.nan_to_num(data['intensity_mean'].values, 0) + np.nan_to_num(data['arousal_mean'].values, 0)

# %%
fig, axs = plt.subplots(3, 3, figsize=(9, 9))
for xi, x in enumerate(['taskVdots_dist_mean','taskVdots_power_mean', 'taskVdots_affil_mean']):
    for yi, y in enumerate(['valence_mean', 'arousal2_mean', 'stability_mean']):
        sns.regplot(x=data[x], y=data[y], scatter_kws={'alpha':0.3, 's':30}, color='darkblue', ax=axs[xi,yi])
plt.tight_layout()
plt.show()

# %%
# less positive, less arousing -> more mismatch
# ... maybe just measuring engagement?
res, ols_obj = run_ols(['valence_mean', 'arousal2_mean', 'memory_mean'], 'taskVdots_dist_mean', 
                       data, covariates=demo_controls)
ols_obj.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     taskVdots_dist_mean   R-squared:                       0.070
# Model:                             OLS   Adj. R-squared:                  0.059
# Method:                  Least Squares   F-statistic:                     6.539
# Date:                 Mon, 05 Dec 2022   Prob (F-statistic):           1.86e-07
# Time:                         00:52:08   Log-Likelihood:                 106.96
# No. Observations:                  617   AIC:                            -197.9
# Df Residuals:                      609   BIC:                            -162.5
# Df Model:                            7
# Covariance Type:             nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Character impression ratings

# %%
ratings = ['friendliness', 'competence', 'dominance', 'popularity', 'likability', 'impact']

# get the difference from self rating
for rating in ratings:
    for char in character_roles: 
        data[f'{char}_{rating}_diff'] = data[f'{char}_{rating}'] - data[f'self_{rating}']
    data[f'{rating}_diff_mean'] = np.mean(data[[f'{char}_{rating}_diff' for char in character_roles]],1)

# %%
fig, axs = plt.subplots(2, 2, figsize=(6,5))
ylims    = [[0,100], [-100,100]]

for r, rating in enumerate(['likability', 'impact_diff']):
    for c, dim in enumerate(['affil', 'power']):
        
        x = f'{dim}_mean_mean'
        y = f'{rating}_mean'
        
        # ols
        _, ols_obj = run_ols([x], y, data, covariates=demo_controls, n_splits=None, plot=False)
        pval = ols_obj.pvalues[1]
        
        # plot
        if ('likability' in rating) & ('affil' in dim):
            color = 'blue'
        elif ('impact_diff' in rating) & ('power' in dim):
            color = 'red'
        else:
            color = 'grey'
        ax = axs[r,c]
        g = sns.regplot(x=data[x], y=data[y], ax=ax, 
                        ci=95, n_boot=1000, truncate=True, 
                        scatter_kws={'alpha':0.33, 's':20}, color=color)
        
        # significance
        x_change = 0.04 # for diff stars    
        sigs = [0.05,0.01,0.005,0.001,0.00005,0.00001]
        for s, sig in enumerate(sigs):
            if pval < sig: 
                ax.text(0.95-x_change*s, 0.98, "*", color=color, fontsize=12, ha="left", va="top", transform=ax.transAxes)
                
#         ax.set_ylim(ylims[c][0], ylims[c][1])
#         if d == 0: ax.set_yticks([0,25,50,75,100])

        if c == 1: 
            ax.set_ylabel('')
        else:
            if rating == 'likability': 
                ax.set_ylabel('Likability', fontsize=14)
            elif rating == 'impact_diff': 
                ax.set_ylabel('Impact Difference', fontsize=14)
        if r == 0: 
            ax.set_xlabel('')
        else:
            if dim == 'affil': 
                ax.set_xlabel('Affiliation', fontsize=14)
            elif dim == 'power': 
                ax.set_xlabel('Power', fontsize=14)
                
        ax.set_xlim(-1, 1) 
        ax.set_xticks([-1,-.5,0,.5,1])
        ax.tick_params(axis='x', labelsize=8)
        ax.tick_params(axis='y', labelsize=8)
                
# handles = [Patch(facecolor=sample_colors[1], edgecolor='black')]
# plt.legend(title='', loc='upper right', handles=handles, labels=['Replication'],
#            title_fontsize=13, fontsize=15,
#            frameon=False, bbox_to_anchor=(1.65, 2.4), 
#            borderaxespad=0)
plt.legend([],[], frameon=False)
# plt.subplots_adjust(left=0.1, bottom=0.1, 
#                     right=0.9, top=0.9, 
#                     wspace=0.4, hspace=0.4)
fig.align_ylabels(axs[:, 0])
fig.tight_layout()

# %% [markdown]
# ### CCA's for dots, task & ratings combos...

# %%
task = data[['affil_mean_mean', 'power_mean_mean']]
dots = data[['dots_affil_mean', 'dots_power_mean', 'memory_mean']] 
ratings = data[['impact_diff_mean', 'likability_mean', 'memory_mean']]

for cc in [[task, dots], [ratings, task], [ratings, dots]]:

    mask = np.sum(np.isfinite(cc[0]), 1) == cc[0].shape[1]
    cc[0] = scipy.stats.zscore(cc[0][mask])
    cc[1] = scipy.stats.zscore(cc[1][mask])
    cca = CanCorr(cc[0], cc[1]) # order doesnt matter
    print(cca.corr_test().summary())
# Out:
#                            Cancorr results
# ...
#   Canonical Correlation Wilks' lambda Num DF   Den DF  F Value Pr > F
# ---------------------------------------------------------------------
# 0                0.2492        0.9285 6.0000 1822.0000 11.4749 0.0000
# 1                0.1002        0.9900 2.0000  912.0000  4.6253 0.0100
# ---------------------------------------------------------------------
#
# ---------------------------------------------------------------------
# Multivariate Statistics and F Approximations
# -----------------------------------------------------------------------
#                          Value    Num DF     Den DF    F Value   Pr > F
# -----------------------------------------------------------------------
# Wilks' lambda            0.9285   6.0000   1820.0000   11.4623   0.0000
# Pillai's trace           0.0721   6.0000   1822.0000   11.3600   0.0000
# Hotelling-Lawley trace   0.0763   6.0000   1211.5572   11.5707   0.0000
# ...

# %% [markdown]
# ### Distances in rating space
# - average pairwise is ~area
# - what about others? why do this.. lol

# %%
[c for c in data.columns if 'likability' in c]
# Out:
# ['second_likability',
#  'first_likability',
#  'boss_likability',
#  'neutral_likability',
#  'assistant_likability',
#  'powerful_likability',
#  'likability_mean',
#  'attention_likability',
#  'first_likability_self',
#  'second_likability_self',
#  'powerful_likability_self',
#  'boss_likability_self',
#  'assistant_likability_self',
#  'neutral_likability_self',
#  'self_likability',
#  'marriage_01_likability',
#  'parents_01_likability',
#  'parents_02_likability',
#  'inlaws_01_likability',
#  'dating_01_likability',
#  'relatives_01_likability',
#  'relatives_02_likability',
#  'work_supervision_01_likability',
#  'work_supervision_02_likability',
#  'work_supervision_03_likability',
#  'work_nonsupervision_01_likability',
#  'children_01_likability',
#  'children_02_likability',
#  'friends_01_likability',
#  'friends_02_likability',
#  'school_01_likability',
#  'work_nonsupervision_02_likability',
#  'work_nonsupervision_03_likability',
#  'friends_03_likability',
# ...

# %%
dists = []
rating_vars = ['likability', 'impact']
for i in range(len(data)):
    try:
        ratings = []
        for rating_ in rating_vars:
            ratings.append(list(data.loc[i, [f'{role}_{rating_}' for role in character_roles]].values))
        ratings = np.array(ratings).T
        dists.append(np.mean(pairwise_distances(ratings)))
    except:
        dists.append(np.nan)
        continue
         
# all_df['rating_dists'] = dists
# for beh in ['allo3d_volume', 'ego_dists_end_mean', 'factor_social', 'lsas_av_score']:
#     fig,ax = plt.subplots(figsize=(5,5))
#     sns.regplot(x=all_df['rating_dists'], y=all_df[beh], color='blue')
#     add_sig_stars('rating_dists', beh, all_df, demo_controls, ax=ax, color="blue")
#     plt.show()

# %% [markdown]
# # Free response: sentiment analysis
# - not sure how to qc this...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sentiment = SentimentIntensityAnalyzer()
def word_count(string):
    return(len(string.split(" ")))

for role in character_roles[0:5]:
    free_resps = data[f'free_response_{role}'].values
    num_words, negative, positive, neutral = [], [], [], []
    for fr in free_resps:
        try:    
            num_words.append(word_count(fr))
            polarity = sentiment.polarity_scores(fr)
            negative.append(polarity['neg'])
            positive.append(polarity['pos'])
            neutral.append(polarity['neu'])
        except: 
            num_words.append(np.nan)
            positive.append(np.nan)
            negative.append(np.nan)
            neutral.append(np.nan)

    data[f'free_response_{role}_num_words'] = num_words
    data[f'free_response_{role}_positive'] = positive
    data[f'free_response_{role}_negative'] = negative
    data[f'free_response_{role}_neutral'] = neutral

data['free_response_num_words_mean'] = np.mean(data[[c for c in data.columns if ('free' in c) & ('num_words' in c)]], axis=1)
data['free_response_positive_mean'] = np.mean(data[[c for c in data.columns if ('free' in c) & ('positive' in c) & ('sia' not in c)]], axis=1)
data['free_response_negative_mean'] = np.mean(data[[c for c in data.columns if ('free' in c) & ('negative' in c) & ('sia' not in c)]], axis=1)
data['free_response_neutral_mean'] = np.mean(data[[c for c in data.columns if ('free' in c) & ('neutral' in c) & ('sia' not in c)]], axis=1)

# %%
fig, axs = plt.subplots(3, 3, figsize=(9, 9))
for xi, x in enumerate(['free_response_positive_mean', 'free_response_negative_mean', 'free_response_neutral_mean']):
    for yi, y in enumerate(['pov_dist_mean', 'affil_mean_mean', 'power_mean_mean']):
        sns.regplot(x=data[x], y=data[y], ax=axs[yi,xi], 
                    scatter_kws={'alpha':0.33, 's':30})
plt.tight_layout()
plt.show()

# ols
results, obj = run_ols(['free_response_positive_mean','free_response_num_words_mean', 'memory_mean'], 'pov_dist_mean', data, 
                       covariates=demo_controls) #  'free_response_negative_mean',
obj.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          pov_dist_mean   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     2.510
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):             0.0120
# Time:                        00:55:31   Log-Likelihood:                -481.64
# No. Observations:                 292   AIC:                             981.3
# Df Residuals:                     283   BIC:                             1014.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Questions about task engagement etc...

# %%
data[[c for c in data.columns if 'storyline' in c]]
# Out:
#                                         storyline_good  \
# 0                         they were thought provoking.
# 1                                     absolutely none.
# 2     i had no problems and could answer the questi...
# 3     they were interesting. i like making my own c...
# 4     the tasks kept me interested even when i was ...
# ..                                                 ...
# 921   the characters seemed to be internally consis...
# 922   i liked that the choices i made changed how t...
# 923          it was interesting and easy to get into.
# 924                     it was realistic and engaging.
# 925   i liked the variety of characters. they had d...
#
#                                          storyline_bad  storyline_engagement  \
# 0                        nothing that i can think of.                      9
# 1     i had to restart the entire task because the ...                     2
# ...

# %%
# first asked about it on 1-10 scale, then on 1-100 scale
# so should fix this...

init_mask = data['sample'] == 0
repl_mask = data['sample'] == 1

init_ques = data[init_mask][['storyline_engagement','storyline_difficulty','storyline_relatability']] * 10
repl_ques = data[repl_mask][['storyline_engagement','storyline_difficulty','storyline_relatability']]
data[['storyline_engagement_rescaled','storyline_difficulty_rescaled','storyline_relatability_rescaled']] = pd.concat([init_ques, repl_ques])

# %%
fig, axs = plt.subplots(1,3, figsize=(8,3))
sns.histplot(data['storyline_engagement_rescaled'], bins=10, ax=axs[0])
sns.histplot(data['storyline_difficulty_rescaled'], bins=10, ax=axs[1])
sns.histplot(data['storyline_relatability_rescaled'], bins=10, ax=axs[2])
plt.tight_layout()
plt.show()

# %%
xvars = ['demo_age','memory_mean', 'valence_mean']
yvars = ['storyline_engagement_rescaled','storyline_difficulty_rescaled','storyline_relatability_rescaled']

fig, axs = plt.subplots(len(xvars), len(yvars), figsize=(9, 2*len(yvars)))
for xi, x in enumerate(xvars):
    for yi, y in enumerate(yvars):
        sns.regplot(x=data[x], y=data[y], scatter_kws={'alpha':0.3, 's':30}, color='darkblue', ax=axs[xi,yi])
        axs[xi,yi].set_ylabel(y.split('_')[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Combining

# %%
for s, sample in enumerate(['original','replication']):

    df = data[data['sample'] == s]
    if sample == 'replication':
        nrows = 3
    else:
        nrows = 2
    fig, axs = plt.subplots(nrows, 5, figsize=(20, 3.75*nrows))
    fig.subplots_adjust(top=0.95)
    fig.text(0.5, 0.01, 'Affiliation', ha='center', fontsize=30)
    fig.text(0.04, 0.5, 'Power', va='center', rotation='vertical', fontsize=30)

    rank_binedges = np.array([0,1,2,3,4,5])
    norm_binedges = np.array([-1,-.6,-.2,.2,.6,1]) 

    for c, char in enumerate(character_roles[0:5]):
        
        axs[0,c].set_title(character_roles[c].capitalize(), fontsize=20)
        
        task_affil = df['affil_mean_' + char]
        task_power = df['power_mean_' + char]
        axs[0,c].hist2d(task_affil, task_power, bins=[norm_binedges, norm_binedges], color=character_colors[c])
        axs[0,c].set_ylabel('Behavior', fontsize=20)
        axs[0,c].axis([-1, 1, -1, 1])

        dots_power = df[char + '_dots_power']
        dots_affil = df[char + '_dots_affil']
        axs[1,c].hist2d(dots_affil, dots_power, bins=[norm_binedges, norm_binedges], color=character_colors[c])
        axs[1,c].set_ylabel('Dots', fontsize=20)
        axs[1,c].axis([-1, 1, -1, 1])
        
        if sample == 'replication':
            likability = (df[char + '_likability'] - 50)/50
            impact = df[f'{char}_impact_diff']/100
            axs[2,c].hist2d(likability, impact, bins=[norm_binedges, norm_binedges], color=character_colors[c])
            axs[2,c].set_ylabel('Rating', fontsize=20)
            axs[2,c].axis([-1, 1, -1, 1])

        if c > 0: [axs[r,c].axes.get_yaxis().set_visible(False) for r in np.arange(0,nrows)] 

    # fig.savefig(fig_dir + "/behavior_dots.png", dpi=150)
    # plt.show()

# %%
behavior   = ['affil_mean_mean', 'power_mean_mean',
              'Q1_overlap', 'Q2_overlap', 'Q3_overlap', 'Q4_overlap']
selfreport = ['demo_ladder_rate', 'factor_social_min', 'apdis_score'] # maybe should ask how many friends they have or something as another..?
posttask   = ['dots_affil_mean', 'dots_power_mean','likability_mean','impact_diff_mean']

#------------------------------------------------------------
#------------------------------------------------------------

x_ = data[behavior].copy()
y_ = data[selfreport + posttask].copy()
coefs, pvals = get_asymmetrical_corrmat(x_, y_)
display(pvals)
plot = plot_asymmetrical_corrmat(coefs, pvals, figsize=(8,6))
# Out:
#                    affil_mean_mean  power_mean_mean  Q1_overlap    Q2_overlap  \
# demo_ladder_rate      2.634487e-01     9.992597e-02    0.249877  5.428145e-02
# factor_social_min     1.504150e-04     1.718498e-05    0.041520  2.314217e-06
# apdis_score           2.524854e-04     2.750140e-05    0.272903  1.325419e-08
# zbpd_score            7.471402e-01     5.080162e-01    0.481059  2.762864e-01
# dots_affil_mean       3.494145e-05     7.160387e-01    0.219833  1.981098e-03
# dots_power_mean       8.488734e-04     6.148104e-03    0.002160  6.482125e-01
# likability_mean       7.044031e-12     1.747745e-01    0.443407  9.796193e-09
# impact_diff_mean      4.748835e-01     6.373697e-09    0.000010  3.148821e-04
#
#                      Q3_overlap    Q4_overlap
# demo_ladder_rate   4.683127e-01  4.244918e-02
# factor_social_min  9.120790e-01  1.011982e-07
# apdis_score        9.227004e-01  4.820068e-07
# zbpd_score         5.224339e-01  2.970681e-01
# ...
